# %% [markdown]
# # Sonoma County Animal Services
# ## Exploratory Data Analysis
#
# Initial exploratory data analysis for Sonoma County Animal Services (SCAS) animal data and rough-draft testing of visualizations and graphs.

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## OVERVIEW

# %%
SCAS_data = pd.read_csv("Resources/Animal_Shelter_Intake_and_Outcome.csv")
SCAS_data.head(15)
# Out:
#         Name   Type                    Breed           Color       Sex   Size  \
# 0      RAZOR    DOG           BOSTON TERRIER     BLACK/WHITE  Neutered  SMALL
# 1        NaN  OTHER                   PIGEON      GRAY/WHITE   Unknown  SMALL
# 2        MAX    DOG            BORDER COLLIE  BLACK/TRICOLOR  Neutered    MED
# 3        NaN    CAT              DOMESTIC LH      GRAY/WHITE    Spayed  SMALL
# 4      PUDGY    DOG  CHIHUAHUA SH/SCHIPPERKE             TAN  Neutered    MED
# 5       LEXI    DOG          AUST CATTLE DOG     WHITE/BLACK    Spayed    MED
# 6        NaN  OTHER                      BAT           BLACK   Unknown  SMALL
# 7      KENJI    DOG                    AKITA        TRICOLOR  Neutered  LARGE
# 8     SONOMA  OTHER                    HORSE     BROWN/BLACK    Female  LARGE
# 9       COCO    DOG           GREAT PYRENEES           WHITE    Spayed  LARGE
# 10  *TABITHA    CAT              DOMESTIC SH           BLACK    Spayed  KITTN
# 11       NaN  OTHER        BAT/MEX FREE-TAIL            GRAY   Unknown  SMALL
# 12    NAKITA    DOG           SIBERIAN HUSKY     BLACK/WHITE    Female  LARGE
# 13   *PEPPER    CAT              DOMESTIC SH     BLACK/WHITE  Neutered  KITTN
# 14     SATIN  OTHER                    HORSE     BLACK/WHITE    Female  LARGE
#
#    Date Of Birth Impound Number Kennel Number Animal ID  ...  \
# 0     10/29/2009     K22-043412         TRUCK   A396382  ...
# 1            NaN     K23-044095         TRUCK   A416206  ...
# 2     03/10/2020     K23-044090          DS80   A399488  ...
# 3     06/26/2011     K22-043405           VET   A414520  ...
# 4     07/20/2013     K23-043813          DA27   A415428  ...
# 5     04/01/2022     K22-041089          DS49   A410937  ...
# 6            NaN     K23-044072          EUTH   A416138  ...
# 7     05/02/2022     K22-042314         DQ114   A412962  ...
# 8            NaN     K21-040124        CHANGE   A407842  ...
# 9     02/21/2022     K22-042491          DS66   A413774  ...
# 10    07/14/2022     K22-042942         LOBBY   A413866  ...
# 11           NaN     K23-044087         TRUCK   A416186  ...
# 12           NaN     K21-040409          DS68   A414560  ...
# 13    08/29/2022     K22-042992          CA02   A413965  ...
# 14           NaN     K21-040123        CHANGE   A407841  ...
#
#       Intake Subtype     Outcome Type          Outcome Subtype  \
# 0              FIELD  RETURN TO OWNER                FLD_IDTAG
# 1              FIELD        EUTHANIZE               INJ SEVERE
# 2              FIELD  RETURN TO OWNER    OVER THE COUNTER_CALL
# 3              FIELD         DISPOSAL                      DOA
# 4   OVER THE COUNTER         TRANSFER                MUTTVILLE
# 5              FIELD  RETURN TO OWNER    OVER THE COUNTER_PRVS
# 6              FIELD        EUTHANIZE                      FRA
# 7              FIELD  RETURN TO OWNER  OVER THE COUNTER_WALKIN
# 8         FLD_HOSPTL         TRANSFER                      NaN
# 9         FLD_LIVSTK  RETURN TO OWNER     OVER THE COUNTER_WEB
# 10  OVER THE COUNTER         ADOPTION                   WALKIN
# 11             FIELD        EUTHANIZE                      FRA
# 12             FIELD  RETURN TO OWNER    OVER THE COUNTER_PRVS
# 13  OVER THE COUNTER         ADOPTION                   WALKIN
# 14        FLD_HOSPTL         TRANSFER                      NaN
#
#    Intake Condition Outcome Condition Intake Jurisdiction  \
# 0           UNKNOWN           HEALTHY          SANTA ROSA
# 1           UNKNOWN           HEALTHY          SANTA ROSA
# 2           UNKNOWN           PENDING              COUNTY
# 3           UNKNOWN              DEAD              COUNTY
# 4           UNKNOWN           HEALTHY          SANTA ROSA
# 5           UNKNOWN           PENDING          SANTA ROSA
# 6           UNKNOWN       UNTREATABLE              COUNTY
# 7           UNKNOWN           PENDING          SANTA ROSA
# 8           UNKNOWN   TREATABLE/REHAB              COUNTY
# 9           UNKNOWN           PENDING              COUNTY
# 10          HEALTHY           HEALTHY          SANTA ROSA
# 11          UNKNOWN           HEALTHY              COUNTY
# 12          UNKNOWN           PENDING          SANTA ROSA
# 13          HEALTHY           HEALTHY              COUNTY
# 14          UNKNOWN   TREATABLE/REHAB              COUNTY
#
#    Outcome Jurisdiction Outcome Zip Code                     Location Count
# 0            SANTA ROSA          95404.0  95404(38.43807, -122.71247)     1
# 1                   NaN              NaN                          NaN     1
# 2                COUNTY          95472.0  95472(38.40179, -122.82512)     1
# 3            SANTA ROSA          95403.0  95403(38.51311, -122.75502)     1
# 4         OUT OF COUNTY          94103.0  94103(37.77672, -122.40779)     1
# 5            SANTA ROSA          95407.0  95407(38.41483, -122.72707)     1
# 6                   NaN              NaN                          NaN     1
# 7            SANTA ROSA          95407.0  95407(38.41483, -122.72707)     1
# 8                COUNTY          95404.0  95404(38.43807, -122.71247)     1
# 9                COUNTY          95465.0   95465(38.4071, -122.94753)     1
# 10               COUNTY          95589.0  95589(40.06054, -123.96838)     1
# 11                  NaN              NaN                          NaN     1
# 12           SANTA ROSA          95407.0  95407(38.41483, -122.72707)     1
# 13           SANTA ROSA          95403.0  95403(38.51311, -122.75502)     1
# 14               COUNTY          95404.0  95404(38.43807, -122.71247)     1
#
# [15 rows x 24 columns]

# %%
del SCAS_data["Impound Number"]
del SCAS_data["Kennel Number"]
SCAS_data.head()
# Out:
#     Name   Type                    Breed           Color       Sex   Size  \
# 0  RAZOR    DOG           BOSTON TERRIER     BLACK/WHITE  Neutered  SMALL
# 1    NaN  OTHER                   PIGEON      GRAY/WHITE   Unknown  SMALL
# 2    MAX    DOG            BORDER COLLIE  BLACK/TRICOLOR  Neutered    MED
# 3    NaN    CAT              DOMESTIC LH      GRAY/WHITE    Spayed  SMALL
# 4  PUDGY    DOG  CHIHUAHUA SH/SCHIPPERKE             TAN  Neutered    MED
#
#   Date Of Birth Animal ID Intake Date Outcome Date  ...    Intake Subtype  \
# 0    10/29/2009   A396382  12/26/2022   12/26/2022  ...             FIELD
# 1           NaN   A416206  03/15/2023   03/15/2023  ...             FIELD
# 2    03/10/2020   A399488  03/15/2023   03/15/2023  ...             FIELD
# 3    06/26/2011   A414520  12/23/2022   12/27/2022  ...             FIELD
# 4    07/20/2013   A415428  02/08/2023   03/15/2023  ...  OVER THE COUNTER
#
#       Outcome Type        Outcome Subtype Intake Condition Outcome Condition  \
# 0  RETURN TO OWNER              FLD_IDTAG          UNKNOWN           HEALTHY
# 1        EUTHANIZE             INJ SEVERE          UNKNOWN           HEALTHY
# 2  RETURN TO OWNER  OVER THE COUNTER_CALL          UNKNOWN           PENDING
# 3         DISPOSAL                    DOA          UNKNOWN              DEAD
# 4         TRANSFER              MUTTVILLE          UNKNOWN           HEALTHY
#
#   Intake Jurisdiction Outcome Jurisdiction Outcome Zip Code  \
# 0          SANTA ROSA           SANTA ROSA          95404.0
# 1          SANTA ROSA                  NaN              NaN
# 2              COUNTY               COUNTY          95472.0
# 3              COUNTY           SANTA ROSA          95403.0
# 4          SANTA ROSA        OUT OF COUNTY          94103.0
#
#                       Location  Count
# 0  95404(38.43807, -122.71247)      1
# 1                          NaN      1
# 2  95472(38.40179, -122.82512)      1
# 3  95403(38.51311, -122.75502)      1
# 4  94103(37.77672, -122.40779)      1
#
# [5 rows x 22 columns]

# %%
SCAS_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24936 entries, 0 to 24935
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  18384 non-null  object
#  1   Type                  24936 non-null  object
#  2   Breed                 24936 non-null  object
#  3   Color                 24936 non-null  object
#  4   Sex                   24936 non-null  object
#  5   Size                  24901 non-null  object
#  6   Date Of Birth         18741 non-null  object
#  7   Animal ID             24936 non-null  object
#  8   Intake Date           24936 non-null  object
#  9   Outcome Date          24790 non-null  object
#  10  Days in Shelter       24936 non-null  int64
#  11  Intake Type           24936 non-null  object
#  12  Intake Subtype        24936 non-null  object
#  13  Outcome Type          24784 non-null  object
#  14  Outcome Subtype       24467 non-null  object
#  15  Intake Condition      24936 non-null  object
#  16  Outcome Condition     24440 non-null  object
#  17  Intake Jurisdiction   24936 non-null  object
#  18  Outcome Jurisdiction  21447 non-null  object
#  19  Outcome Zip Code      21390 non-null  float64
#  20  Location              21390 non-null  object
#  21  Count                 24936 non-null  int64
# dtypes: float64(1), int64(2), object(19)
# memory usage: 4.2+ MB

# %%
# Find how many types of animals come in through SCAS
animal_types = SCAS_data["Type"].unique()
print(animal_types)
# Out:
# ['DOG' 'OTHER' 'CAT']

# %%
# Isolate only 
SCAS_dogs = SCAS_data.loc[SCAS_data["Type"] == "DOG"]
SCAS_dogs
# Out:
#           Name Type                    Breed           Color       Sex   Size  \
# 0        RAZOR  DOG           BOSTON TERRIER     BLACK/WHITE  Neutered  SMALL
# 2          MAX  DOG            BORDER COLLIE  BLACK/TRICOLOR  Neutered    MED
# 4        PUDGY  DOG  CHIHUAHUA SH/SCHIPPERKE             TAN  Neutered    MED
# 5         LEXI  DOG          AUST CATTLE DOG     WHITE/BLACK    Spayed    MED
# 7        KENJI  DOG                    AKITA        TRICOLOR  Neutered  LARGE
# ...        ...  ...                      ...             ...       ...    ...
# 24927      NaN  DOG                 PIT BULL      BLUE/WHITE    Female    MED
# 24929    SPIDY  DOG         CHIHUAHUA SH/MIX       BLACK/TAN      Male  SMALL
# 24930      NaN  DOG          AUST CATTLE DOG       TAN/BLACK   Unknown  PUPPY
# 24933   SHINER  DOG                 PIT BULL       TAN/WHITE  Neutered  LARGE
# 24934  *NEWTON  DOG         CHIHUAHUA SH/MIX     BROWN/WHITE  Neutered  SMALL
#
#       Date Of Birth Animal ID Intake Date Outcome Date  ...    Intake Subtype  \
# 0        10/29/2009   A396382  12/26/2022   12/26/2022  ...             FIELD
# 2        03/10/2020   A399488  03/15/2023   03/15/2023  ...             FIELD
# 4        07/20/2013   A415428  02/08/2023   03/15/2023  ...  OVER THE COUNTER
# 5        04/01/2022   A410937  04/11/2022   06/02/2022  ...             FIELD
# 7        05/02/2022   A412962  08/23/2022   08/23/2022  ...             FIELD
# ...             ...       ...         ...          ...  ...               ...
# 24927    02/05/2015   A395973  02/05/2020   02/21/2020  ...             FIELD
# 24929           NaN   A397912  06/14/2020   06/14/2020  ...             FIELD
# 24930    02/21/2022   A410244  02/24/2022   02/26/2022  ...         BORN_HERE
# 24933    12/22/2012   A293651  09/11/2014   10/02/2014  ...  OVER THE COUNTER
# 24934    07/28/2011   A398415  07/02/2020   08/20/2020  ...             FIELD
#
#           Outcome Type          Outcome Subtype Intake Condition  \
# 0      RETURN TO OWNER                FLD_IDTAG          UNKNOWN
# 2      RETURN TO OWNER    OVER THE COUNTER_CALL          UNKNOWN
# 4             TRANSFER                MUTTVILLE          UNKNOWN
# 5      RETURN TO OWNER    OVER THE COUNTER_PRVS          UNKNOWN
# 7      RETURN TO OWNER  OVER THE COUNTER_WALKIN          UNKNOWN
# ...                ...                      ...              ...
# 24927         TRANSFER                     CWOB          HEALTHY
# 24929  RETURN TO OWNER                FLD_IDTAG          HEALTHY
# 24930         TRANSFER                     HDBQ  TREATABLE/REHAB
# 24933        EUTHANIZE               AGGRESSIVE      UNTREATABLE
# 24934         TRANSFER               ROCKET DOG          HEALTHY
#
#       Outcome Condition Intake Jurisdiction Outcome Jurisdiction  \
# 0               HEALTHY          SANTA ROSA           SANTA ROSA
# 2               PENDING              COUNTY               COUNTY
# 4               HEALTHY          SANTA ROSA        OUT OF COUNTY
# 5               PENDING          SANTA ROSA           SANTA ROSA
# 7               PENDING          SANTA ROSA           SANTA ROSA
# ...                 ...                 ...                  ...
# 24927           HEALTHY              COUNTY               COUNTY
# 24929           HEALTHY          SANTA ROSA           SANTA ROSA
# 24930   TREATABLE/REHAB          SANTA ROSA        OUT OF COUNTY
# 24933       UNTREATABLE          SANTA ROSA               COUNTY
# 24934           HEALTHY          SANTA ROSA        OUT OF COUNTY
#
#       Outcome Zip Code                     Location  Count
# 0              95404.0  95404(38.43807, -122.71247)      1
# 2              95472.0  95472(38.40179, -122.82512)      1
# 4              94103.0  94103(37.77672, -122.40779)      1
# 5              95407.0  95407(38.41483, -122.72707)      1
# 7              95407.0  95407(38.41483, -122.72707)      1
# ...                ...                          ...    ...
# 24927          95407.0  95407(38.41483, -122.72707)      1
# 24929          95403.0  95403(38.51311, -122.75502)      1
# 24930          94044.0    94044(37.63527, -122.492)      1
# 24933          95476.0  95476(38.29188, -122.45728)      1
# 24934          94146.0                        94146      1
#
# [14058 rows x 22 columns]

# %%
SCAS_cats = SCAS_data.loc[SCAS_data["Type"] == "CAT"]
SCAS_cats
# Out:
#            Name Type        Breed            Color       Sex   Size  \
# 3           NaN  CAT  DOMESTIC LH       GRAY/WHITE    Spayed  SMALL
# 10     *TABITHA  CAT  DOMESTIC SH            BLACK    Spayed  KITTN
# 13      *PEPPER  CAT  DOMESTIC SH      BLACK/WHITE  Neutered  KITTN
# 17          NaN  CAT  DOMESTIC SH        BRN TABBY    Spayed  SMALL
# 19        *RYAN  CAT  DOMESTIC SH      BLACK/WHITE  Neutered  SMALL
# ...         ...  ...          ...              ...       ...    ...
# 24916       NaN  CAT  DOMESTIC SH            BLACK   Unknown  KITTN
# 24920     *BART  CAT  DOMESTIC SH  BRN TABBY/WHITE  Neutered  KITTN
# 24926     *BUZZ  CAT  DOMESTIC SH             GRAY  Neutered    MED
# 24928       NaN  CAT  DOMESTIC SH      BLACK/WHITE    Spayed  SMALL
# 24931      BUBA  CAT  DOMESTIC SH       GRAY/WHITE  Neutered  SMALL
#
#       Date Of Birth Animal ID Intake Date Outcome Date  ...    Intake Subtype  \
# 3        06/26/2011   A414520  12/23/2022   12/27/2022  ...             FIELD
# 10       07/14/2022   A413866  10/25/2022   12/27/2022  ...  OVER THE COUNTER
# 13       08/29/2022   A413965  10/29/2022   12/27/2022  ...  OVER THE COUNTER
# 17       12/14/2007   A414446  12/14/2022   12/27/2022  ...  OVER THE COUNTER
# 19       01/12/2022   A414137  11/12/2022   12/27/2022  ...  OVER THE COUNTER
# ...             ...       ...         ...          ...  ...               ...
# 24916           NaN   A335189  04/05/2016   04/05/2016  ...          COMM CAT
# 24920    04/02/2021   A406572  09/02/2021   10/07/2021  ...  OVER THE COUNTER
# 24926    05/16/2016   A363866  11/04/2017   11/25/2017  ...  OVER THE COUNTER
# 24928    05/12/2014   A344967  11/12/2016   11/17/2016  ...          COMM CAT
# 24931    10/15/2017   A392014  10/03/2019   10/23/2019  ...  OVER THE COUNTER
#
#           Outcome Type Outcome Subtype Intake Condition Outcome Condition  \
# 3             DISPOSAL             DOA          UNKNOWN              DEAD
# 10            ADOPTION          WALKIN          HEALTHY           HEALTHY
# 13            ADOPTION          WALKIN          HEALTHY           HEALTHY
# 17            DISPOSAL             DOA          UNKNOWN              DEAD
# 19            ADOPTION          WALKIN          HEALTHY           HEALTHY
# ...                ...             ...              ...               ...
# 24916         TRANSFER       FORGOTTEN          HEALTHY           HEALTHY
# 24920         TRANSFER            HSSC          UNKNOWN           HEALTHY
# 24926         ADOPTION          WALKIN          UNKNOWN           HEALTHY
# 24928  RETURN TO OWNER         COMMCAT          HEALTHY           HEALTHY
# 24931         ADOPTION          WALKIN          HEALTHY           HEALTHY
#
#       Intake Jurisdiction Outcome Jurisdiction Outcome Zip Code  \
# 3                  COUNTY           SANTA ROSA          95403.0
# 10             SANTA ROSA               COUNTY          95589.0
# 13                 COUNTY           SANTA ROSA          95403.0
# 17                 COUNTY                  NaN              NaN
# 19                 COUNTY           SANTA ROSA          95403.0
# ...                   ...                  ...              ...
# 24916              COUNTY           SANTA ROSA          95403.0
# 24920          SANTA ROSA               COUNTY          95407.0
# 24926          SANTA ROSA           SANTA ROSA          95405.0
# 24928              COUNTY               COUNTY          94952.0
# 24931          SANTA ROSA          *HEALDSBURG          95448.0
#
#                           Location  Count
# 3      95403(38.51311, -122.75502)      1
# 10     95589(40.06054, -123.96838)      1
# 13     95403(38.51311, -122.75502)      1
# 17                             NaN      1
# 19     95403(38.51311, -122.75502)      1
# ...                            ...    ...
# 24916  95403(38.51311, -122.75502)      1
# 24920  95407(38.41483, -122.72707)      1
# 24926  95405(38.44473, -122.68655)      1
# 24928  94952(38.23262, -122.64426)      1
# 24931  95448(38.61064, -122.86883)      1
#
# [8832 rows x 22 columns]

# %%
SCAS_other = SCAS_data.loc[SCAS_data["Type"] == "OTHER"]
SCAS_other
# Out:
#            Name   Type              Breed        Color      Sex   Size  \
# 1           NaN  OTHER             PIGEON   GRAY/WHITE  Unknown  SMALL
# 6           NaN  OTHER                BAT        BLACK  Unknown  SMALL
# 8        SONOMA  OTHER              HORSE  BROWN/BLACK   Female  LARGE
# 11          NaN  OTHER  BAT/MEX FREE-TAIL         GRAY  Unknown  SMALL
# 14        SATIN  OTHER              HORSE  BLACK/WHITE   Female  LARGE
# ...         ...    ...                ...          ...      ...    ...
# 24820       NaN  OTHER          RABBIT SH  BLACK/WHITE  Unknown  SMALL
# 24901       NaN  OTHER            CHICKEN        BROWN   Female  SMALL
# 24924       NaN  OTHER                BAT        BROWN  Unknown  SMALL
# 24932  *JESSICA  OTHER           AMERICAN  WHITE/BROWN   Spayed  SMALL
# 24935       NaN  OTHER              SHEEP        WHITE   Female  LARGE
#
#       Date Of Birth Animal ID Intake Date Outcome Date  ...    Intake Subtype  \
# 1               NaN   A416206  03/15/2023   03/15/2023  ...             FIELD
# 6               NaN   A416138  03/13/2023   03/13/2023  ...             FIELD
# 8               NaN   A407842  11/15/2021   03/15/2023  ...        FLD_HOSPTL
# 11              NaN   A416186  03/15/2023   03/15/2023  ...             FIELD
# 14              NaN   A407841  11/15/2021   03/15/2023  ...        FLD_HOSPTL
# ...             ...       ...         ...          ...  ...               ...
# 24820    06/23/2016   A338690  06/23/2016   06/23/2016  ...         BORN_HERE
# 24901           NaN   A384150  02/01/2019   02/14/2019  ...             FIELD
# 24924           NaN   A400012  08/18/2020   08/18/2020  ...             FIELD
# 24932    11/08/2017   A374156  06/20/2018   10/10/2018  ...  OVER THE COUNTER
# 24935           NaN   A369354  03/12/2018   03/13/2018  ...             FIELD
#
#           Outcome Type Outcome Subtype Intake Condition Outcome Condition  \
# 1            EUTHANIZE      INJ SEVERE          UNKNOWN           HEALTHY
# 6            EUTHANIZE             FRA          UNKNOWN       UNTREATABLE
# 8             TRANSFER             NaN          UNKNOWN   TREATABLE/REHAB
# 11           EUTHANIZE             FRA          UNKNOWN           HEALTHY
# 14            TRANSFER             NaN          UNKNOWN   TREATABLE/REHAB
# ...                ...             ...              ...               ...
# 24820        EUTHANIZE      UNDERAGEWT      UNTREATABLE       UNTREATABLE
# 24901         ADOPTION        FB OTHER          UNKNOWN           PENDING
# 24924              NaN             NaN          UNKNOWN               NaN
# 24932         TRANSFER            HSSC          HEALTHY           HEALTHY
# 24935  RETURN TO OWNER             NaN          UNKNOWN               NaN
#
#       Intake Jurisdiction Outcome Jurisdiction Outcome Zip Code  \
# 1              SANTA ROSA                  NaN              NaN
# 6                  COUNTY                  NaN              NaN
# 8                  COUNTY               COUNTY          95404.0
# 11                 COUNTY                  NaN              NaN
# 14                 COUNTY               COUNTY          95404.0
# ...                   ...                  ...              ...
# 24820              COUNTY                  NaN              NaN
# 24901              COUNTY        OUT OF COUNTY          95482.0
# 24924              COUNTY                  NaN              NaN
# 24932          SANTA ROSA               COUNTY          95407.0
# 24935              COUNTY               COUNTY          95472.0
#
#                           Location  Count
# 1                              NaN      1
# 6                              NaN      1
# 8      95404(38.43807, -122.71247)      1
# 11                             NaN      1
# 14     95404(38.43807, -122.71247)      1
# ...                            ...    ...
# 24820                          NaN      1
# 24901   95482(39.15093, -123.2079)      1
# 24924                          NaN      1
# 24932  95407(38.41483, -122.72707)      1
# 24935  95472(38.40179, -122.82512)      1
#
# [2046 rows x 22 columns]

# %%
# Find out what kinds of animals are typed as "OTHER"
other_types = SCAS_other["Breed"].unique()
print(other_types)
# Out:
# ['PIGEON' 'BAT' 'HORSE' 'BAT/MEX FREE-TAIL' 'DUCK/MUSCOVY' 'CHICKEN'
#  'OTHER BIRD' 'RABBIT SH' 'HAVANA/MIX' 'SHEEP' 'GUINEA PIG' 'DUCK'
#  'LOVEBIRD' 'LOP-AMER FUZZY' 'FINCH' 'HAMSTER' 'CANARY' 'PEAFOWL' 'GOAT'
#  'ENGLISH SPOT/MIX' 'CALIFORNIAN/MIX' 'DOVE' 'ENGLISH SPOT'
#  'LOP-HOLLAND/MIX' 'RABBIT LH' 'LIZARD' 'DWARF HOTOT' 'REX' 'KOI'
#  'PARAKEET' 'SHETLAND' 'LOP-MINI' 'FLEMISH GIANT' 'POTBELLY PIG' 'TURTLE'
#  'GOAT/BOER' 'AMERICAN' 'JERSEY/MIX' 'PIG' 'COCKATIEL' 'RAT'
#  'LOP-MINI/MIX' 'BOER' 'LOP-FRENCH' 'TROPICAL' 'REX/MIX' 'NETHERLND DWARF'
#  'GOOSE' 'JERSEY' 'DUTCH' 'CHINCHILLA' 'LOP-ENGLISH' 'MOUSE' 'PARROT'
#  'ANGUS' 'SNAKE' 'RACCOON' 'OPOSSUM' 'FOX' 'LOP-AMER FUZZY/MIX' 'LILAC'
#  'RABBIT LH/MIX' 'HARLEQUIN/MIX' 'FERRET' 'COCKATOO' 'SILVER' 'HAVANA'
#  'GOAT/LA MANCHA' 'NEW ZEALAND WHT/MIX' 'COLD WATER' 'MACAW'
#  'RHODE ISLAND' 'AMERICAN/REX' 'THOROUGHBRED' 'RHINELANDER/MIX' 'POLISH'
#  'SILVER/MIX' 'HOTOT' 'ANGORA-SATIN' 'SQUIRREL' 'MULE' 'ANGORA-ENGLISH'
#  'LOP-ENGLISH/MIX' 'DUTCH/MIX' 'HOTOT/MIX' 'CALIFORNIAN' 'SKUNK'
#  'NETHERLND DWARF/MIX' 'TORTOISE' 'NEW ZEALAND WHT' 'HIMALAYAN/MIX'
#  'PAINT' 'QUAIL' 'BELGIAN HARE/MIX' 'PALOMINO' 'HAWK' 'FLORIDA WHITE'
#  'LOP-HOLLAND' 'LA MANCHA' 'GOAT/PYGMY' 'ANGORA-SATIN/MIX' 'BANTAM'
#  'PERUVIAN PASO' 'CONURE' 'MUSCOVY' 'DONKEY' 'BUDGERIGAR' 'DUCK/CAYUGA'
#  'PYGMY' 'SNAKE/RATTLE' 'GOAT/NUBIAN' 'REX-MINI/MIX' 'BARRED ROCK'
#  'CHICKEN/BANTAM' 'PONY' 'AMERICAN SABLE/MIX' 'ARAUCANA' 'QUARTER HORSE'
#  'LEGHORN' 'GOAT/ALPINE' 'ARABIAN' 'PALOMINO/MIX' 'AMERICAN/MIX'
#  'APPALOOSA' 'TURKEY' 'JACK' 'HERON' 'HORSE/PAINT' 'CHAMPGN DARGENT'
#  'ALPINE/MIX' 'ANGORA-FRENCH/FLEMISH GIANT' 'DEGU' 'LLAMA']

# %%
# What are the different outcome subtypes for each outcome type?
outcome_counts = SCAS_data["Outcome Type"].value_counts()
outcome_subtypes = pd.DataFrame(SCAS_data.groupby(["Outcome Type", "Outcome Subtype"])["Animal ID"].count())
print(outcome_counts)
print(outcome_subtypes)
# Out:
# RETURN TO OWNER    8384
# ADOPTION           7327
# TRANSFER           5228
# EUTHANIZE          3386
# DISPOSAL            227
# DIED                167
# RTOS                 48
# ESCAPED/STOLEN       17
# Name: Outcome Type, dtype: int64
#                               Animal ID
# Outcome Type Outcome Subtype
# ADOPTION     49ER PET                83
#              AD NWSPAPR              13
#              AD RADIO                 1
#              ADVERT                   4
#              DEBBIE BTQ              15
# ...                                 ...
# TRANSFER     WILD RESCU              11
#              WINE CNTRY              17
#              WONDER                   5
#              WOOD RVR V               4
#              WOOFPROJ                 7
#
# [242 rows x 1 columns]

# %%
# adopted_data looks at ALL animal types: cat, dog, other.
# What are the overall most popular ways that people adopt our animals? Through walk-ins? Our website? Social media?
adopted_data = SCAS_data.loc[SCAS_data["Outcome Type"] == "ADOPTION"]
adoption_subtype_count = adopted_data.groupby("Outcome Subtype")["Animal ID"].count().sort_values(ascending=False)
print("Different outcome subtypes for adoptions:")
print(adoption_subtype_count.head(10))
# Out:
# Different outcome subtypes for adoptions:
# Outcome Subtype
# WALKIN        3390
# SCAS WEB      1433
# INTERNET       848
# WESTFARM       453
# REFERRAL       278
# SPEC EVENT     199
# REFERRAL-O     107
# FINDER          97
# 49ER PET        83
# VOLUNTEER       76
# Name: Animal ID, dtype: int64

# %%
adoption_subtypes = adopted_data["Outcome Subtype"].unique()
print(f"There are {len(adoption_subtypes)} different subtypes for adoptions.")
print(adoption_subtypes)
# Out:
# There are 24 different subtypes for adoptions.
# ['WALKIN' 'REFERRAL-F' 'SCAS WEB' 'FINDER' 'VOLUNTEER' 'INSTAGRAM' nan
#  'INTERNET' 'FB SCAS' 'SPEC EVENT' 'WESTFARM' 'OTH_MEDIA' '49ER PET'
#  'MOB EVENT' 'REFERRAL-O' 'REFERRAL' 'AD RADIO' 'RESCUE GRP' 'REFERRAL-V'
#  'FB OTHER' 'FACEBOOK' 'AD NWSPAPR' 'DEBBIE BTQ' 'ADVERT']

# %% [markdown]
# ### Animal Outcomes
#
# What are the outcomes for animals in the care of Sonoma County Animal Services?

# %%
# Create a bar graph for outcomes of dogs
x_axis = np.arange(len(SCAS_dogs["Outcome Type"].unique()))
tick_loc = [value+0.4 for value in x_axis]

outcome_counts = pd.DataFrame(SCAS_dogs["Outcome Type"].value_counts().sort_index()).reset_index()

outcome_counts = outcome_counts.rename(columns={"index":"Outcome Type", "Outcome Type":"Number of Animals"})

outcome_counts
# Out:
#       Outcome Type  Number of Animals
# 0         ADOPTION               3291
# 1             DIED                 31
# 2         DISPOSAL                 35
# 3   ESCAPED/STOLEN                  5
# 4        EUTHANIZE               1514
# 5  RETURN TO OWNER               7023
# 6             RTOS                 37
# 7         TRANSFER               2026

# %%
plt.figure(figsize=(11,8))
plt.xticks(tick_loc, rotation = "vertical", fontsize=12)
plt.xlabel("Outcome Type", fontsize=20)
plt.ylabel("Number of Animals",fontsize=20)
plt.title("Outcome Type for Dogs", fontsize=24)

plt.bar(outcome_counts["Outcome Type"], outcome_counts["Number of Animals"])

plt.show()

# %% [markdown]
# ### Adopted Animals by Breed/Kind
#
# Of all the animals that were adopted, which breeds or kinds of animals were more popular for adoption?

# %%
adoptedDogs = SCAS_dogs.loc[SCAS_dogs["Outcome Type"] == "ADOPTION"]
adoptedDogs_breeds = adoptedDogs["Breed"].value_counts()
adoptedDogs_breeds.head(20)
# Out:
# CHIHUAHUA SH           383
# PIT BULL               328
# PIT BULL/MIX           199
# CHIHUAHUA SH/MIX       184
# GERM SHEPHERD          174
# GERM SHEPHERD/MIX      102
# SIBERIAN HUSKY          92
# LABRADOR RETR/MIX       86
# PARSON RUSS TER/MIX     77
# BORDER COLLIE/MIX       46
# CAIRN TERRIER/MIX       41
# LABRADOR RETR           37
# POODLE MIN              30
# DACHSHUND/MIX           27
# POODLE MIN/MIX          27
# AUST CATTLE DOG/MIX     26
# PARSON RUSS TER         26
# CHIHUAHUA LH            23
# YORKSHIRE TERR/MIX      22
# POMERANIAN/MIX          22
# Name: Breed, dtype: int64

# %%
TopAdopted_Dogs = adoptedDogs_breeds.head(20).plot(kind="bar",figsize=(16,8))
TopAdopted_Dogs.set_xlabel("Breed")
TopAdopted_Dogs.set_ylabel("Number of Animals Adopted")
plt.title("Top 20 Adopted Dog Breeds")
plt.show()
plt.tight_layout()

# %%
# and now for cats
adoptedCats = SCAS_cats.loc[SCAS_cats["Outcome Type"] == "ADOPTION"]
adoptedCats_breeds = adoptedCats["Breed"].value_counts()
adoptedCats_breeds.head(20)
# Out:
# DOMESTIC SH               2788
# DOMESTIC MH                350
# DOMESTIC LH                235
# SIAMESE/MIX                 89
# SIAMESE                     70
# HIMALAYAN/MIX                7
# HIMALAYAN                    7
# MANX                         6
# SNOWSHOE/MIX                 5
# SNOWSHOE                     4
# ABYSSINIAN/MIX               4
# DOMESTIC SH/MIX              3
# MANX/MIX                     3
# PERSIAN                      3
# DOMESTIC LH/MAINE COON       3
# SCOTTISH FOLD/MIX            3
# DOMESTIC SH/ABYSSINIAN       2
# TURKISH ANGORA               2
# PERSIAN/MIX                  2
# DOMESTIC LH/SIAMESE          2
# Name: Breed, dtype: int64

# %%
TopAdopted_Cats = adoptedCats_breeds.head(20).plot(kind="bar",figsize=(16,8))
TopAdopted_Cats.set_xlabel("Breed")
TopAdopted_Cats.set_ylabel("Number of Animals Adopted")
plt.title("Top 20 Adopted Cat Breeds")
plt.show()
plt.tight_layout()

# %%
adoptedOther = SCAS_other.loc[SCAS_other["Outcome Type"] == "ADOPTION"]
adoptedOther_breeds = adoptedOther["Breed"].value_counts()
adoptedOther_breeds.head(20)
# Out:
# RABBIT SH           68
# CHICKEN             61
# GUINEA PIG          46
# PARAKEET            27
# PIG                 19
# COCKATIEL           15
# PEAFOWL             14
# GOOSE               13
# RAT                 13
# GOAT                11
# SHEEP                9
# KOI                  8
# LOP-MINI             8
# HAMSTER              6
# FINCH                5
# GOAT/LA MANCHA       5
# HAVANA/MIX           5
# ENGLISH SPOT/MIX     4
# DUTCH/MIX            4
# LOP-HOLLAND          4
# Name: Breed, dtype: int64

# %%
TopAdopted_Other = adoptedOther_breeds.head(20).plot(kind="bar",figsize=(16,8))
TopAdopted_Other.set_xlabel("Kind")
TopAdopted_Other.set_ylabel("Number of Animals Adopted")
plt.title("Top 20 Kinds of Other Animals Adopted")
plt.show()
plt.tight_layout()
